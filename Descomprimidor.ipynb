# %%
import zipfile
import os
import shutil

def descomprimir_varios_zip(ruta_origen, ruta_temporal, ruta_destino_final):
    # Crear carpetas si no existen
    os.makedirs(ruta_temporal, exist_ok=True)
    os.makedirs(ruta_destino_final, exist_ok=True)

    # Recorrer todos los archivos en la carpeta origen
    for archivo in os.listdir(ruta_origen):
        ruta_zip = os.path.join(ruta_origen, archivo)

        # Verificar si es un archivo ZIP
        if zipfile.is_zipfile(ruta_zip):
            print(f"\nProcesando archivo: {archivo}")

            # Crear subcarpeta única para cada archivo descomprimido
            subcarpeta_temporal = os.path.join(ruta_temporal, os.path.splitext(archivo)[0])
            os.makedirs(subcarpeta_temporal, exist_ok=True)

            # Descomprimir en la subcarpeta temporal
            with zipfile.ZipFile(ruta_zip, 'r') as archivo_zip:
                archivo_zip.extractall(subcarpeta_temporal)
                print(f"Descomprimido en: {subcarpeta_temporal}")

            # Mover los archivos al destino final
            for nombre in os.listdir(subcarpeta_temporal):
                origen = os.path.join(subcarpeta_temporal, nombre)
                destino = os.path.join(ruta_destino_final, nombre)

                if os.path.exists(destino):
                    print(f"Advertencia: ya existe {nombre} en destino. Se sobreescribirá.")

                shutil.move(origen, destino)

            print(f"Archivos de {archivo} movidos a: {ruta_destino_final}")
        else:
            print(f"Archivo ignorado (no es ZIP): {archivo}")

# Rutas personalizadas
ruta_carpeta_zip = r"D:\Personal\Facturas\Facturas electronicas"
ruta_temporal = r"D:\Personal\Facturas\TemporalZip"
ruta_destino = r"D:\Personal\Facturas\FacturasDescomprimidas"

descomprimir_varios_zip(ruta_carpeta_zip, ruta_temporal, ruta_destino)
# Out:
# Procesando archivo: 0800242106021244205100300126.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\0800242106021244205100300126
# Archivos de 0800242106021244205100300126.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: 0800242106021244206100309407.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\0800242106021244206100309407
# Archivos de 0800242106021244206100309407.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: 0800242106021244206100314279.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\0800242106021244206100314279
# Archivos de 0800242106021244206100314279.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: 800128735_RFRV46743.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\800128735_RFRV46743
# Archivos de 800128735_RFRV46743.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: 800128735_RFRV46744.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\800128735_RFRV46744
# Archivos de 800128735_RFRV46744.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad080022505702724671220240608104718721.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad080022505702724671220240608104718721
# Archivos de ad080022505702724671220240608104718721.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad081100783202724409320240216202307899.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad081100783202724409320240216202307899
# Archivos de ad081100783202724409320240216202307899.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad081100783202724634720240608022136322.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad081100783202724634720240608022136322
# Archivos de ad081100783202724634720240608022136322.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad081100783202724846520241021192903667.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad081100783202724846520241021192903667
# Archivos de ad081100783202724846520241021192903667.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0811009788000202469573023.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0811009788000202469573023
# Archivos de ad0811009788000202469573023.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0811009788000202475971717.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0811009788000202475971717
# Archivos de ad0811009788000202475971717.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0811009788000202476875729.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0811009788000202476875729
# Archivos de ad0811009788000202476875729.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0811009788000202484061176.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0811009788000202484061176
# Archivos de ad0811009788000202484061176.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900072683000202417089965.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900072683000202417089965
# Archivos de ad0900072683000202417089965.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900072683000202417551507.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900072683000202417551507
# Archivos de ad0900072683000202417551507.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900072683000202418868150.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900072683000202418868150
# Archivos de ad0900072683000202418868150.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900072683000202420746776.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900072683000202420746776
# Archivos de ad0900072683000202420746776.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900072683000202421667013.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900072683000202421667013
# Archivos de ad0900072683000202421667013.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900072683000202423107706.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900072683000202423107706
# Archivos de ad0900072683000202423107706.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900072683000202423563860.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900072683000202423563860
# Archivos de ad0900072683000202423563860.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900072683000202424535308.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900072683000202424535308
# Archivos de ad0900072683000202424535308.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900072683000202425616621.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900072683000202425616621
# Archivos de ad0900072683000202425616621.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900072683000202429882646.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900072683000202429882646
# Archivos de ad0900072683000202429882646.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900453780000202404688852.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900453780000202404688852
# Archivos de ad0900453780000202404688852.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900453780000202406843027.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900453780000202406843027
# Archivos de ad0900453780000202406843027.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900453780000202407919250.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900453780000202407919250
# Archivos de ad0900453780000202407919250.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0900453780000202411570039.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0900453780000202411570039
# Archivos de ad0900453780000202411570039.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad0901288343000202405407761.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad0901288343000202405407761
# Archivos de ad0901288343000202405407761.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad090130074102724200020240816232012546.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad090130074102724200020240816232012546
# Archivos de ad090130074102724200020240816232012546.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad090130074102724246020241202212347792.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad090130074102724246020241202212347792
# Archivos de ad090130074102724246020241202212347792.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad090130074102724269720240822201104712.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad090130074102724269720240822201104712
# Archivos de ad090130074102724269720240822201104712.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad090130074102724302720240911202018971.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad090130074102724302720240911202018971
# Archivos de ad090130074102724302720240911202018971.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad090130074102724343220240826201330093.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad090130074102724343220240826201330093
# Archivos de ad090130074102724343220240826201330093.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad090130074102724402820241109211135627.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad090130074102724402820241109211135627
# Archivos de ad090130074102724402820241109211135627.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad090130074102724432420241101222443518.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad090130074102724432420241101222443518
# Archivos de ad090130074102724432420241101222443518.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad090130074102724560020240926184734095.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad090130074102724560020240926184734095
# Archivos de ad090130074102724560020240926184734095.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: ad090130074102724704620240819171735061.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\ad090130074102724704620240819171735061
# Archivos de ad090130074102724704620240819171735061.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: fv80023693710532402486101.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\fv80023693710532402486101
# Archivos de fv80023693710532402486101.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z08605031590102405086626.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z08605031590102405086626
# Archivos de z08605031590102405086626.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z08909044780152400000956.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z08909044780152400000956
# Archivos de z08909044780152400000956.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z08909044780152400001751.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z08909044780152400001751
# Archivos de z08909044780152400001751.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z08909044780152400030119.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z08909044780152400030119
# Archivos de z08909044780152400030119.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z0900219834000240030a64e.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z0900219834000240030a64e
# Archivos de z0900219834000240030a64e.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z0900219834000240061ba3c.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z0900219834000240061ba3c
# Archivos de z0900219834000240061ba3c.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z090021983400024006baa63.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z090021983400024006baa63
# Archivos de z090021983400024006baa63.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z090021983400024006cc774.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z090021983400024006cc774
# Archivos de z090021983400024006cc774.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z090021983400024006fe217.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z090021983400024006fe217
# Archivos de z090021983400024006fe217.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z0900219834000240071efd2.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z0900219834000240071efd2
# Archivos de z0900219834000240071efd2.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z090021983400024007220f3.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z090021983400024007220f3
# Archivos de z090021983400024007220f3.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z09002198340002400724a98.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z09002198340002400724a98
# Archivos de z09002198340002400724a98.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z090021983400024008cf92e.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z090021983400024008cf92e
# Archivos de z090021983400024008cf92e.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z090021983400024008e6098 (1).zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z090021983400024008e6098 (1)
# Archivos de z090021983400024008e6098 (1).zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z090021983400024008e6098.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z090021983400024008e6098
# Advertencia: ya existe ad090021983400024008e6098.xml en destino. Se sobreescribirá.
# Advertencia: ya existe de090021983400024008e6098.pdf en destino. Se sobreescribirá.
# Archivos de z090021983400024008e6098.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas
#
# Procesando archivo: z09016018260892400003879.zip
# Descomprimido en: D:\Personal\Facturas\TemporalZip\z09016018260892400003879
# Archivos de z09016018260892400003879.zip movidos a: D:\Personal\Facturas\FacturasDescomprimidas

# %%
import os
import fitz  # PyMuPDF
import re

def extraer_ultimo_valor_y_sumar(ruta_carpeta):
    total = 0.0
    patron_valor = re.compile(r'(?<!\d)(\d{1,3}(?:\.\d{3})*|\d+)(?:,\d{2})?')  # valores con puntos y comas

    for archivo in os.listdir(ruta_carpeta):
        if archivo.lower().endswith('.pdf'):
            ruta_pdf = os.path.join(ruta_carpeta, archivo)
            try:
                doc = fitz.open(ruta_pdf)
                texto = ""
                for pagina in doc:
                    texto += pagina.get_text()
                doc.close()

                # Buscar todos los valores numéricos
                valores_encontrados = patron_valor.findall(texto)

                if valores_encontrados:
                    ultimo_valor = valores_encontrados[-1]
                    valor_limpio = ultimo_valor.replace('.', '').replace(',', '.')
                    total += float(valor_limpio)
                    print(f"{archivo}: último valor encontrado = {valor_limpio}")
                else:
                    print(f"{archivo}: no se encontraron valores numéricos.")
            except Exception as e:
                print(f"Error procesando {archivo}: {e}")

    print(f"\n💰 Total sumado (último valor de cada PDF): {total:,.2f}")

# Ruta donde están los archivos PDF
ruta_pdf = r"D:\Personal\Facturas\FacturasDescomprimidas"

extraer_ultimo_valor_y_sumar(ruta_pdf)
# Out:
# 800128735_RFRV46743.pdf: último valor encontrado = 1
# 800128735_RFRV46744.pdf: último valor encontrado = 1
# 8002369371_01_FD24817275_10777202.pdf: último valor encontrado = 0
# ad080022505702724671220240608104718721.pdf: último valor encontrado = 06202
# ad081100783202724409320240216202307899.pdf: último valor encontrado = 38600
# ad081100783202724634720240608022136322.pdf: último valor encontrado = 06202
# ad081100783202724846520241021192903667.pdf: último valor encontrado = 10202
# ad08605031590102405086626.pdf: último valor encontrado = 204
# ad090130074102724200020240816232012546.pdf: último valor encontrado = 202
# ad090130074102724246020241202212347792.pdf: último valor encontrado = 202
# ad090130074102724269720240822201104712.pdf: último valor encontrado = 202
# ad090130074102724302720240911202018971.pdf: último valor encontrado = 202
# ad090130074102724343220240826201330093.pdf: último valor encontrado = 202
# ad090130074102724402820241109211135627.pdf: último valor encontrado = 202
# ad090130074102724432420241101222443518.pdf: último valor encontrado = 202
# ad090130074102724560020240926184734095.pdf: último valor encontrado = 202
# ad090130074102724704620240819171735061.pdf: último valor encontrado = 202
# ad09016018260892400003879.pdf: último valor encontrado = 1
# de090021983400024006cc774.pdf: último valor encontrado = 1
# de0900219834000240071efd2.pdf: último valor encontrado = 1
# de090021983400024007220f3.pdf: último valor encontrado = 1
# de09002198340002400724a98.pdf: último valor encontrado = 1
# de090021983400024008cf92e.pdf: último valor encontrado = 1
# de090021983400024008e6098.pdf: último valor encontrado = 1
# fv0800242106021244205100300126.pdf: último valor encontrado = 8
# fv0800242106021244206100309407.pdf: último valor encontrado = 8
# fv0800242106021244206100314279.pdf: último valor encontrado = 8
# fv0811009788000202469573023.pdf: último valor encontrado = 754
# fv0811009788000202475971717.pdf: último valor encontrado = 754
# fv0811009788000202476875729.pdf: último valor encontrado = 754
# fv0811009788000202484061176.pdf: último valor encontrado = 754
# fv08909044780152400030119.pdf: último valor encontrado = 92
# fv0900072683000202417089965.pdf: último valor encontrado = 130
# fv0900072683000202417551507.pdf: último valor encontrado = 130
# fv0900072683000202418868150.pdf: último valor encontrado = 130
# fv0900072683000202420746776.pdf: último valor encontrado = 130
# fv0900072683000202421667013.pdf: último valor encontrado = 130
# fv0900072683000202423107706.pdf: último valor encontrado = 130
# fv0900072683000202423563860.pdf: último valor encontrado = 130
# fv0900072683000202424535308.pdf: último valor encontrado = 130
# fv0900072683000202425616621.pdf: último valor encontrado = 130
# fv0900072683000202429882646.pdf: último valor encontrado = 130
# fv0900219834000240030a64e.pdf: último valor encontrado = 1
# fv0900219834000240061ba3c.pdf: último valor encontrado = 2
# fv090021983400024006baa63.pdf: último valor encontrado = 1
# fv090021983400024006fe217.pdf: último valor encontrado = 1
# fv0900453780000202404688852.pdf: último valor encontrado = 104
# fv0900453780000202406843027.pdf: último valor encontrado = 104
# fv0900453780000202407919250.pdf: último valor encontrado = 104
# fv0900453780000202411570039.pdf: último valor encontrado = 104
# fv0901288343000202405407761.pdf: último valor encontrado = 104
# z08909044780152400000956.pdf: último valor encontrado = 5
# z08909044780152400001751.pdf: último valor encontrado = 1
#
# 💰 Total sumado (último valor de cada PDF): 68,200.00
